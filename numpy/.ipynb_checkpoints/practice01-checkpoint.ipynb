# %%
import numpy as np

a = np.array([2,3,5])

print(a)
a
# Out:
# [2 3 5]
# array([2, 3, 5])

# %%
type(a)
len(a)
# Out:
# 3

# %%
b = np.array([[5,45,345],[345,6344,656]])
print(b)

len(b)
# Out:
# [[   5   45  345]
#  [ 345 6344  656]]
# 2

# %%
c = np.
