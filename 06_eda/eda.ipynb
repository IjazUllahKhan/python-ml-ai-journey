# %%
# Imports important libraries

import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()

# %%
titanic.to_csv("titanic.csv")

# %%
titanic.info()

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic[["sex",'who']].nunique()

# %%
titanic[["sex", "who"]].apply(lambda col: col.unique())

# %% [markdown]
# # Cleaning and Filtering Data

# %%
# Find missing values inside
titanic.isnull().sum()

# %%
# Removing missing value column (cleaning data)
titanic02 = titanic.drop(["deck"], axis = 1)

# %%
titanic02.isnull().sum()

# %%
titanic02.shape
# Out:
# (891, 14)

# %%
titanic03 = titanic02.dropna()
titanic03.shape
# Out:
# (712, 14)

# %%
titanic03.isnull().sum()

# %%
titanic03["sex"].value_counts()
