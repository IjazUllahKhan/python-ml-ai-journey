# %% [markdown]
# # Importing Libraries

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Loading Data set

# %%
titanic = sns.load_dataset("titanic")
# Out:
# (891, 15)

# %% [markdown]
# # Checking key attributes of the data Frame

# %%
print("shape: ",titanic.shape)
print("Columns Header: ",titanic.columns)
print("Rows Number: ",titanic.index)
print("Data Type of each coloumn : \n",titanic.dtypes)

# %% [markdown]
# #  Available buildin dataset in seaborn

# %%
print(sns.get_dataset_names())

# %% [markdown]
# # Creating Data frame from a dictionary of series

# %%
df3 = pd.DataFrame({
    "A": pd.Series([1, 2, 3], index=[100, 101, 102]),
    "B": pd.Series([4, 5, 6], index=[100, 101, 102])
})
print(df3)
